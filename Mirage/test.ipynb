# %%
from utils.agg_pref_summary import summarize_preferences

alpha_csv = "/home2/liyang/GitHub/Mirage/Mirage/savedloggers/_Aug.15_22.21.22_fedavg/alpha_estimates.csv"
out_json  = "/home2/liyang/GitHub/Mirage/Mirage/savedloggers/_Aug.15_22.21.22_fedavg/prefs_fixed.json"

summary = summarize_preferences(alpha_csv, out_json_path=out_json, debug=True, sample_n=12)

from pprint import pprint
print("\n== per_region (from returned dict) ==")
pprint(summary["per_region"])
# Out:
# == CSV HEADER ==
# ['iteration', 'region_id', 'k_mal', 'P_total', 'b_real_l2', 'b_sim_l2', 'b_cos_dist', 'b_l2_pct_diff', 'l2_radius', 'cosine_threshold', 'update_cone_mode', 'alpha_update', 'est_mode', 'a_raw', 'b_raw', 'alpha_update_real', 'est_mode_real', 'a_raw_real', 'b_raw_real', 'alpha_gap_abs', 'alpha_gap_rel']
# Total rows: 52
#
# == SELECTED KEYS ==
# alpha key     : alpha_update
# k_mal key     : k_mal
# P_total key   : P_total
# l2_radius key : l2_radius
# dir key       : update_cone_mode
# region_id key : region_id
#
# == SAMPLE ROWS (iteration, region_id, alpha_total, k_mal, P_total) ==
# iter=2001, region=4, alpha=0.2986181676387787, k_mal=3, P_total=10
# iter=2002, region=2, alpha=0.2877878248691559, k_mal=3, P_total=10
# iter=2003, region=3, alpha=0.30494585633277893, k_mal=3, P_total=10
# iter=2004, region=1, alpha=0.2927047908306122, k_mal=3, P_total=10
# iter=2005, region=4, alpha=0.29495319724082947, k_mal=3, P_total=10
# ...
